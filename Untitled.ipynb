# %%
import numpy as np
import pandas as pd

pd.set_option('display.float_format', '{:.10f}'.format)

# %%
df = pd.read_excel("palabras por importancia.xlsx", sheet_name="Hoja3").iloc[:,:-1]

# %%
df.shape
# Out:
# (5963, 23)

# %%
df.head(10)
# Out:
#     Palabras clave  Agropecuario      Compras  Construcción   Contaduria  \
# 0        abarrotes  0.0000000000 0.0005094169  0.0000000000 0.0000000000
# 1      abastecedor  0.0000000000 0.0000000000  0.0000000000 0.0000000000
# 2   abastecimiento  0.0000000000 0.0103547272  0.0000000000 0.0000000000
# 3  abastecimientos  0.0000000000 0.0009861930  0.0000000000 0.0000000000
# 4   abastesimiento  0.0000000000 0.0009861930  0.0000000000 0.0000000000
# 5          abastos  0.0000000000 0.0000000000  0.0000000000 0.0000000000
# 6              abc  0.0000000000 0.0000000000  0.0000000000 0.0000000000
# 7          abierta  0.0000000000 0.0000000000  0.0000000000 0.0000000000
# 8          abogado  0.0000000000 0.0000000000  0.0000000000 0.0000000000
# 9            abono  0.0000000000 0.0000000000  0.0000000000 0.0000000000
#
#         Diseño    Educación   Financiero  Gastronomia  Gestión de Calidad  \
# 0 0.0000000000 0.0000000000 0.0000000000 0.0000000000        0.0000000000
# ...

# %%
df.tail(10)
# Out:
#      Palabras clave  Agropecuario      Compras  Construcción   Contaduria  \
# 5953          zonal  0.0000000000 0.0000000000  0.0000000000 0.0000000000
# 5954      zonanorte  0.0000000000 0.0000000000  0.0000000000 0.0000000000
# 5955          zonas  0.0000000000 0.0000000000  0.0008355573 0.0000000000
# 5956    zonificador  0.0000000000 0.0000000000  0.0000000000 0.0000000000
# 5957      zootecnia  0.0023364490 0.0000000000  0.0000000000 0.0000000000
# 5958    zootecnista  0.0130767985 0.0000000000  0.0000000000 0.0000000000
# 5959   zootecnistas  0.0000000000 0.0000000000  0.0000000000 0.0000000000
# 5960             zp  0.0000000000 0.0000000000  0.0000000000 0.0000000000
# 5961          zulia  0.0000000000 0.0000000000  0.0000000000 0.0000000000
# 5962       zunchado  0.0000000000 0.0000000000  0.0000000000 0.0000000000
#
#            Diseño    Educación   Financiero  Gastronomia  Gestión de Calidad  \
# ...

# %%
columns = df.columns[1:]
columns
# Out:
# Index(['Agropecuario', 'Compras', 'Construcción', 'Contaduria', 'Diseño',
#        'Educación', 'Financiero', 'Gastronomia', 'Gestión de Calidad',
#        'Juridicos', 'Logistica', 'Marketing', 'Operativo',
#        'Practicantes - Aprendices', 'Project Manager', 'Psicologia',
#        'Recursos Humanos', 'Salud', 'Servicio al cliente', 'SST', 'Talento TI',
#        'Ventas - Comercial - Administración'],
#       dtype='object')
